# %% [markdown]
# # Projeto Python + Banco de Dados
#
# Este projeto tem como objetivo integrar a biblioteca `pandas` com o uso de bancos de dados relacionais utilizando `SQLAlchemy`. O foco está em carregar, manipular e consultar dados de forma eficiente.

# %% [markdown]
# ## 📦 Importando bibliotecas

# %%
from sqlalchemy import create_engine, text, MetaData, inspect, Table
import pandas as pd

# %% [markdown]
# ## 🛠 Criando a conexão com banco de dados

# %%
engine = create_engine('sqlite:///:memory:')

# %% [markdown]
# ## 🔍 Inspeção do banco de dados

# %%
inspector = inspect(engine)

# %% [markdown]
# ## 📂 Importando dados

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
aluguel = pd.read_csv(url, sep=';')
aluguel.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %% [markdown]
# ## 🧾 Salvando dados no banco

# %%
aluguel.to_sql('aluguel', engine, index = False)
# Out:
# 32960

# %%
inspector.get_table_names()
# Out:
# ['aluguel']

# %% [markdown]
# ## Lista de tarefas a realizar:

# %% [markdown]
# Cada tarefa vai possuir o codigo python integrado com banco de dados e o codigo python usando apenas a biblioteca pandas

# %% [markdown]
# 1. Filtrar os imoveis pelo apenas pelo tipo apartamento
#
# 2. Contar quantos imóveis existem por tipo (ex: Casa, Apartamento, etc.)
#
# 3. Selecionar os imóveis com área maior que 100 m²
#
# 4. Calcular o valor médio do aluguel dos imóveis que possuem vaga de garagem
#
# 5. Listar os 5 imóveis com o maior valor de condomínio
#
# 6. Selecionar os imóveis cujo IPTU está entre RS 100,00 e RS 500,00
#
# 7. Contar quantos imóveis possuem valor total (aluguel + condomínio + IPTU) superior a R$ 5.000
#
# 8. Agrupar imóveis por número de quartos e calcular o valor médio do aluguel por grupo

# %%
pd.read_sql_table('aluguel', engine)
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 0        40  1700.0       500.0    60.0
# 1       100  7000.0         NaN     NaN
# 2       150  5200.0      4020.0  1111.0
# 3        15   800.0       390.0    20.0
# 4        48   800.0       230.0     NaN
# ...     ...     ...         ...     ...
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0
#
# [32960 rows x 9 columns]

# %% [markdown]
# ### 1. Filtrar os imoveis apenas pelo tipo apartamento

# %%
query = 'SELECT * FROM aluguel WHERE Tipo = "Apartamento"'
pd.read_sql(query, engine)
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0      Apartamento                Centro        1      0       0    15
# 1      Apartamento          Higienópolis        1      0       0    48
# 2      Apartamento          Vista Alegre        3      1       0    70
# 3      Apartamento              Cachambi        2      0       0    50
# 4      Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 19527  Apartamento        Vila Valqueire        2      0       0    52
# 19528  Apartamento                 Méier        2      0       0    70
# 19529  Apartamento           Jacarepaguá        3      1       2    78
# 19530  Apartamento  São Francisco Xavier        2      1       0    48
# 19531  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0       800.0       390.0  20.0
# 1       800.0       230.0   NaN
# 2      1200.0         NaN   NaN
# 3      1300.0       301.0  17.0
# 4      1200.0         NaN   NaN
# ...       ...         ...   ...
# 19527  1000.0       550.0   NaN
# 19528   900.0       490.0  48.0
# 19529  1800.0       800.0  40.0
# 19530  1400.0       509.0  37.0
# 19531  3000.0       760.0   NaN
#
# [19532 rows x 9 columns]

# %%
apartamentos = aluguel[aluguel['Tipo'] == 'Apartamento']
apartamentos
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# 5      1200.0         NaN   NaN
# 6      1300.0       301.0  17.0
# 10     1200.0         NaN   NaN
# ...       ...         ...   ...
# 32951  1000.0       550.0   NaN
# 32953   900.0       490.0  48.0
# 32956  1800.0       800.0  40.0
# 32957  1400.0       509.0  37.0
# 32958  3000.0       760.0   NaN
#
# [19532 rows x 9 columns]

# %% [markdown]
# ### 2. Contar quantos imóveis existem por tipo

# %%
query = 'SELECT Tipo, COUNT(*) FROM aluguel GROUP BY Tipo'
pd.read_sql(query, engine)
# Out:
#                            Tipo  COUNT(*)
# 0                   Apartamento     19532
# 1                   Box/Garagem        82
# 2                          Casa       967
# 3                Casa Comercial       265
# 4            Casa de Condomínio       996
# 5                  Casa de Vila       249
# 6                       Chácara         1
# 7       Conjunto Comercial/Sala      6815
# 8                          Flat       476
# 9       Galpão/Depósito/Armazém       623
# 10                        Hotel         2
# 11                    Indústria         1
# 12                         Loft        51
# 13  Loja Shopping/ Ct Comercial       247
# 14                   Loja/Salão      1426
# 15        Loteamento/Condomínio         5
# 16                Pousada/Chalé         1
# 17               Prédio Inteiro       301
# 18                    Quitinete       836
# 19                       Studio         4
# 20                        Sítio        10
# 21               Terreno Padrão        70

# %%
aluguel.groupby('Tipo').size()
# Out:
# Tipo
# Apartamento                    19532
# Box/Garagem                       82
# Casa                             967
# Casa Comercial                   265
# Casa de Condomínio               996
# Casa de Vila                     249
# Chácara                            1
# Conjunto Comercial/Sala         6815
# Flat                             476
# Galpão/Depósito/Armazém          623
# Hotel                              2
# Indústria                          1
# Loft                              51
# Loja Shopping/ Ct Comercial      247
# Loja/Salão                      1426
# Loteamento/Condomínio              5
# Pousada/Chalé                      1
# Prédio Inteiro                   301
# Quitinete                        836
# Studio                             4
# Sítio                             10
# Terreno Padrão                    70
# dtype: int64

# %% [markdown]
# ### 3. Selecionar os imóveis com área maior que 100 m²

# %%
query = 'SELECT * FROM aluguel WHERE Area > 100'
pd.read_sql(query, engine)
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 1           Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 2      Conjunto Comercial/Sala           Centro        0      3       0   695
# 3                  Apartamento       Copacabana        4      3       1   243
# 4               Prédio Inteiro         Botafogo        0      0       0   536
# ...                        ...              ...      ...    ...     ...   ...
# 13847  Conjunto Comercial/Sala           Centro        0      0       0   140
# 13848              Apartamento          Ipanema        3      1       2   150
# 13849       Casa de Condomínio  Barra da Tijuca        5      3       4   450
# 13850              Box/Garagem           Centro        0      0       0   755
# 13851  Conjunto Comercial/Sala           Centro        0      0       0   250
#
#          Valor  Condominio    IPTU
# 0       5200.0      4020.0  1111.0
# 1      22000.0         NaN     NaN
# 2      35000.0     19193.0  3030.0
# 3      13000.0      2000.0   803.0
# 4      28000.0         NaN  3563.0
# ...        ...         ...     ...
# 13847   4000.0      1412.0   496.0
# 13848  15000.0      1400.0   600.0
# 13849  15000.0      1711.0  2332.0
# 13850  14000.0         NaN     NaN
# 13851   6500.0      4206.0  1109.0
#
# [13852 rows x 9 columns]

# %%
aluguel[aluguel['Area'] > 100]
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 7           Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 15                 Apartamento       Copacabana        4      3       1   243
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# ...                        ...              ...      ...    ...     ...   ...
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32949              Apartamento          Ipanema        3      1       2   150
# 32952       Casa de Condomínio  Barra da Tijuca        5      3       4   450
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
#          Valor  Condominio    IPTU
# 2       5200.0      4020.0  1111.0
# 7      22000.0         NaN     NaN
# 9      35000.0     19193.0  3030.0
# 15     13000.0      2000.0   803.0
# 16     28000.0         NaN  3563.0
# ...        ...         ...     ...
# 32946   4000.0      1412.0   496.0
# 32949  15000.0      1400.0   600.0
# 32952  15000.0      1711.0  2332.0
# 32954  14000.0         NaN     NaN
# 32959   6500.0      4206.0  1109.0
#
# [13852 rows x 9 columns]

# %% [markdown]
# ### 4. Calcular o valor médio do aluguel dos imóveis que possuem vaga de garagem

# %%
query = 'SELECT AVG(Valor) FROM aluguel WHERE Vagas > 0'
pd.read_sql(query, engine)
# Out:
#     AVG(Valor)
# 0  15879.42705

# %%
aluguel[aluguel['Vagas'] > 0]['Valor'].mean()
# Out:
# np.float64(15879.42705010321)

# %% [markdown]
# ###5. Listar os 5 imóveis com o maior valor de condomínio

# %%
query = 'SELECT * FROM aluguel ORDER BY Condominio DESC LIMIT 5'
pd.read_sql(query, engine)
# Out:
#                       Tipo               Bairro  Quartos  Vagas  Suites  \
# 0              Apartamento      Barra da Tijuca        2      1       1
# 1              Apartamento  Lins de Vasconcelos        2      1       0
# 2  Conjunto Comercial/Sala               Centro        0      0       0
# 3           Prédio Inteiro      Barra da Tijuca        0     99       0
# 4           Prédio Inteiro               Centro        0     99       0
#
#     Area     Valor  Condominio     IPTU
# 0    104    3800.0   6552570.0    655.0
# 1     78    1200.0    519000.0    135.0
# 2  11216  874895.0    196291.0      NaN
# 3   8467  677360.0    194741.0  59269.0
# 4   8680  475200.0    190965.0  34720.0

# %%
aluguel.sort_values('Condominio', ascending = False).head(5)
# Out:
#                           Tipo               Bairro  Quartos  Vagas  Suites  \
# 18028              Apartamento      Barra da Tijuca        2      1       1
# 21666              Apartamento  Lins de Vasconcelos        2      1       0
# 23440  Conjunto Comercial/Sala               Centro        0      0       0
# 26552           Prédio Inteiro      Barra da Tijuca        0     99       0
# 29392           Prédio Inteiro               Centro        0     99       0
#
#         Area     Valor  Condominio     IPTU
# 18028    104    3800.0   6552570.0    655.0
# 21666     78    1200.0    519000.0    135.0
# 23440  11216  874895.0    196291.0      NaN
# 26552   8467  677360.0    194741.0  59269.0
# 29392   8680  475200.0    190965.0  34720.0

# %% [markdown]
# ###6. Selecionar os imóveis cujo IPTU está entre RS 100,00 e RS 500,00

# %%
query = 'SELECT * FROM aluguel WHERE IPTU >= 100 AND IPTU <= 500'
pd.read_sql(query, engine)
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                  Apartamento  Barra da Tijuca        2      1       1    67
# 1                  Apartamento           Tijuca        2      1       0   110
# 2                  Apartamento          Ipanema        3      1       1   125
# 3                  Apartamento  Barra da Tijuca        3      3       1   175
# 4                  Apartamento       Copacabana        3      0       0   180
# ...                        ...              ...      ...    ...     ...   ...
# 10487              Apartamento  Barra da Tijuca        2      1       1    85
# 10488              Apartamento  Barra da Tijuca        3      2       0    98
# 10489                Quitinete       Copacabana        1      0       0    22
# 10490  Conjunto Comercial/Sala           Centro        0      0       0   140
# 10491              Apartamento           Leblon        3      0       1    80
#
#         Valor  Condominio   IPTU
# 0      1700.0       589.0  147.0
# 1      1900.0       700.0  138.0
# 2      7000.0      2100.0  463.0
# 3      4200.0      1500.0  500.0
# 4      5500.0      1780.0  420.0
# ...       ...         ...    ...
# 10487  2250.0      1561.0  197.0
# 10488  2300.0       887.0  177.0
# 10489  1500.0       286.0  200.0
# 10490  4000.0      1412.0  496.0
# 10491  3000.0      1010.0  249.0
#
# [10492 rows x 9 columns]

# %%
aluguel[(aluguel['IPTU'] >= 100) & (aluguel['IPTU'] <= 500)]
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 20                 Apartamento  Barra da Tijuca        2      1       1    67
# 21                 Apartamento           Tijuca        2      1       0   110
# 27                 Apartamento          Ipanema        3      1       1   125
# 30                 Apartamento  Barra da Tijuca        3      3       1   175
# 34                 Apartamento       Copacabana        3      0       0   180
# ...                        ...              ...      ...    ...     ...   ...
# 32940              Apartamento  Barra da Tijuca        2      1       1    85
# 32941              Apartamento  Barra da Tijuca        3      2       0    98
# 32945                Quitinete       Copacabana        1      0       0    22
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32947              Apartamento           Leblon        3      0       1    80
#
#         Valor  Condominio   IPTU
# 20     1700.0       589.0  147.0
# 21     1900.0       700.0  138.0
# 27     7000.0      2100.0  463.0
# 30     4200.0      1500.0  500.0
# 34     5500.0      1780.0  420.0
# ...       ...         ...    ...
# 32940  2250.0      1561.0  197.0
# 32941  2300.0       887.0  177.0
# 32945  1500.0       286.0  200.0
# 32946  4000.0      1412.0  496.0
# 32947  3000.0      1010.0  249.0
#
# [10492 rows x 9 columns]

# %% [markdown]
# ###7. Contar quantos imóveis possuem valor total (aluguel + condomínio + IPTU) superior a R$ 5.000

# %%
query = 'SELECT COUNT(*) FROM aluguel WHERE (Valor + Condominio + IPTU) > 5000'
pd.read_sql(query, engine)
# Out:
#    COUNT(*)
# 0      9644

# %%
aluguel[(aluguel['Valor'] + aluguel['Condominio'] + aluguel['IPTU']) > 5000].shape[0]
# Out:
# 9644

# %% [markdown]
# ###8. Agrupar imóveis por número de quartos e calcular o valor médio do aluguel por grupo

# %%
query = 'SELECT Quartos, AVG(Valor) FROM aluguel GROUP BY Quartos'
pd.read_sql(query, engine)
# Out:
#     Quartos     AVG(Valor)
# 0         0   31381.616987
# 1         1    2264.390750
# 2         2    2686.816021
# 3         3    5086.381538
# 4         4   12464.927569
# 5         5   15673.033217
# 6         6   16529.693431
# 7         7   19440.000000
# 8         8   16052.631579
# 9         9   10250.000000
# 10       10   23590.909091
# 11       11   11750.000000
# 12       12   17000.000000
# 13       14    7250.000000
# 14       22   30000.000000
# 15       23    1480.000000
# 16       24   38000.000000
# 17       27   12000.000000
# 18       32    4000.000000
# 19      100  260500.000000

# %%
aluguel.groupby('Quartos')['Valor'].mean()
# Out:
# Quartos
# 0       31381.616987
# 1        2264.390750
# 2        2686.816021
# 3        5086.381538
# 4       12464.927569
# 5       15673.033217
# 6       16529.693431
# 7       19440.000000
# 8       16052.631579
# 9       10250.000000
# 10      23590.909091
# 11      11750.000000
# 12      17000.000000
# 14       7250.000000
# 22      30000.000000
# 23       1480.000000
# 24      38000.000000
# 27      12000.000000
# 32       4000.000000
# 100    260500.000000
# Name: Valor, dtype: float64
